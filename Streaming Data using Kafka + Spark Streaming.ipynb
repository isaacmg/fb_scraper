# %%
from kafka import KafkaConsumer
consumer = KafkaConsumer('test2')
print("begin")
for msg in consumer:
    print (str(msg))
# Out:
# begin
# hi
# ConsumerRecord(topic='test2', partition=0, offset=2, timestamp=1483506129185, timestamp_type=0, key=b'foo', value=b',115285708497149_1700908723268165,,Jeff,video,https://www.facebook.com/1533798696637390/videos/1538495752834351,2016-12-27 10:51:12,7,0,0,6,0,1,0,0,0', checksum=2017823557, serialized_key_size=3, serialized_value_size=149)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=3, timestamp=1483506129617, timestamp_type=0, key=b'foo', value=b",115285708497149_1688165211209183,Come and play Kayak Polo with us in Northampton, MA\n\n(It may not be slalom but it's still quite fun.)\n\nHow long: Seven, (count 'em) seven fun filled weeks!!! March 15, 22, 29 and April 5, 12, 19 and 26!!!\nWhen: From 6:45 to 8:30pm\nWhere: JFK Junior High School in Northampton, MA\nCost: All for the ridiculously low price of $65 for non-ACA members and $50 for ACA members\nWho: Open to all skill levels, (rolling is optional) and a wet exit can be taught.\nRequired equipment: whitewater boat (playboats, river runners and creek boats; actual polo boats are also allowed), skirt, paddle, helmet and PFD.\nWhat we do: Though this isn't our club, here's a look at what you can expect: https://www.youtube.com/watch?v=rLD89lyRia0\n  \nAll are welcome to play and the game is easy to learn.  We'll teach you to play in a relaxed atmosphere and the games are played where all can participate.  In addition to having a lot of fun, all participants improve or de-rust their boat handling skills by just participating.  It's a great workout that can push you way harder than any other type of pool session. Have no doubt that this is a good time.\n\nIf you are a novice boater: Many rank beginners have played in the past; if you don't have a roll and are uncomfortable with being pushed over we will recognize that. \n\nThe only equipment/skills that are needed to play are: a whitewater boat (playboats, river runners and creek boats), a skirt, a paddle, a helmet and a wet exit (rolling is optional).  If you don't have equipment, let us know and we'll see what we can find (no promises though).\n\nIf you are interested or have questions, send along an e-mail to: kayakpolowesternma@gmail.com \n\nHope to SYITP (see you in the pool).\n\nCheers ...,O-Town Kayak Polo 2013-2014,video,https://www.youtube.com/watch?v=rLD89lyRia0,2016-12-20 14:47:30,4,0,0,4,0,0,0,0,0", checksum=1692545773, serialized_key_size=3, serialized_value_size=1878)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=4, timestamp=1483506130053, timestamp_type=0, key=b'foo', value=b',115285708497149_1679591988733172,I received a note from Melissa Grenier for those interested in a canoe cart.\n Ray,  I have this old style canoe cart I\'m trying to sell.  It\'s built solid.  Tires still hold air, has straps.  It shows signs of it\'s age but works as it should.  I think it\'s missing the "kick stand".  Wheels fold down so it can be flatter.  I believe it was like $150 new.  I\'ll take best offer.  If you know anyone that\'s interested send them my way.  Just remember I\'m in CT and I don\'t want to ship it.  Thanks.,Photos from Ray Ingram\'s post,photo,https://www.facebook.com/photo.php?fbid=919357204831401&set=gm.1679591988733172&type=3,2016-12-15 17:39:34,2,0,0,2,0,0,0,0,0', checksum=-1784522173, serialized_key_size=3, serialized_value_size=692)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=5, timestamp=1483506130505, timestamp_type=0, key=b'foo', value=b',115285708497149_1667468879945483,USA Canoe Kayak Calendar Link;\nNew USA Canoe/Kayak Event Calendar\nWe are pleased to introduce our new ECal event calendar, which you can download and sync to any device or calendar app. If you would like to add an event to our calendar, please send your club or LOC events to Aaron Mann (aaron@usack.org)\n,Calendar,link,http://www.teamusa.org/usa-canoe-kayak/calendar,2016-12-08 14:47:55,2,0,0,2,0,0,0,0,0', checksum=1837247209, serialized_key_size=3, serialized_value_size=439)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=6, timestamp=1483506130937, timestamp_type=0, key=b'foo', value=b',115285708497149_1653636181328753,Please take a few minutes to help save water releases on the Ocoee and request that the TVA allow Slalom Races again to help rebuild Whitewater Slalom Racing in the US and the Southeast.,Roger,link,http://www.americanwhitewater.org/content/Article/view/articleid/32664/,2016-11-30 10:20:49,2,0,0,2,0,0,0,0,0', checksum=-1109793644, serialized_key_size=3, serialized_value_size=341)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=7, timestamp=1483506131376, timestamp_type=0, key=b'foo', value=b",115285708497149_1592743254084713,In the hindsight is 20-20 department we decided to take a leaf peeping run today and ended up in New Boston. Route 57 across southern Mass is gorgeous this time of year. Looked like you folks could have had a race today if you had waited a little longer to postpone. Would been a little scratchy but you could have done it.,Photos from Richard Tuthill's post,photo,https://www.facebook.com/photo.php?fbid=1097874253600717&set=gm.1592743254084713&type=3,2016-10-16 14:37:43,2,4,0,1,0,1,0,0,0", checksum=-519914804, serialized_key_size=3, serialized_value_size=524)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=8, timestamp=1483506131810, timestamp_type=0, key=b'foo', value=b",115285708497149_1580913281934377,The Farmington slalom is CANCELED.\nSorry to have kept people's hopes up.  I got some additional data last night that changes my calculations.  It now looks like we won't have race level water for long enough to actually run the race.  I'd hold on longer if Hurricane Matthew's path projections brought it farther north, but there's now no rain the the forecast either.,,status,,2016-10-07 13:39:03,6,19,1,1,0,0,0,5,0", checksum=-1994472805, serialized_key_size=3, serialized_value_size=450)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=9, timestamp=1483506132210, timestamp_type=0, key=b'foo', value=b",115285708497149_1578969142128791,Farmington Slalom (Oct 15-16)\nI've been talking to several people who are connected with managing the Farmington watershed, have studied historical flows, made calculations, gotten on the ground reports from helpful folks as well as Bob the dam keeper (who is super helpful!).  I'm still not completely sure, but I'm hopeful we can have the race.  I currently estimate the chance of the race running are 75%.  I'll update as I get more comfortable with the projections.  I'm giving myself until next Monday end of day and hoping to know before that.,,status,,2016-10-05 19:28:52,10,1,1,10,0,0,0,0,0", checksum=2135186525, serialized_key_size=3, serialized_value_size=632)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=10, timestamp=1483506132629, timestamp_type=0, key=b'foo', value=b",115285708497149_1562305680461804,Valleyfield race Sept 24th and 25th! ,Comp\xc3\xa9tition de slalom \xc2\xabLa Montreal Cotton\xc2\xbb - \xc3\x89dition Valleyfield | Centre d'excellence d'eau vive de Valleyfield,link,http://kayakvalleyfield.org/activite/comp%C3%A9tition-de-slalom-%C2%ABla-montreal-cotton%C2%BB-%C3%A9dition-valleyfield,2016-09-22 14:47:53,6,0,0,6,0,0,0,0,0", checksum=214279158, serialized_key_size=3, serialized_value_size=351)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=11, timestamp=1483506133097, timestamp_type=0, key=b'foo', value=b",115285708497149_1424715654220808,Congratulations to Ashley Nee, Devin McEwan , Casey Eichfeld & Michal Smolen and to all the coaches, parents, paddlers, volunteers and employees of USACK & ACA. The USA will send a full Whitewater Slalom Team to the Rio Olympics. Rafal Smolen (Michal Smolen's Dad) & Silvan Pobraj are the Olympic coaches.   The International Canoe Federation has assigned Olympic Slots to the USA for K1W and C2. Ashley, Devin & Casey qualified the Olympic spots for the USA with their performances at international races in 2015 and qualified for the US Team at Team Trials races in Charlotte, NC & OKC this spring. Casey had already locked down an Olympic spot in C1 so he was already counted as a warm body in the US Olympic delegation. The only remaining question was what Olympic spots other countries would claim and a bit of politics and procedure to verify that the USA could send a K1W and a C2.,,status,,2016-05-20 10:54:09,15,1,1,15,0,0,0,0,0", checksum=-1894375404, serialized_key_size=3, serialized_value_size=971)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=12, timestamp=1483506133536, timestamp_type=0, key=b'foo', value=b",115285708497149_1550774144948291,Valleyfield race Sept 24th and 25th! ,Comp\xc3\xa9tition de slalom \xc2\xabLa Montreal Cotton\xc2\xbb - \xc3\x89dition Valleyfield | Centre d'excellence d'eau vive de Valleyfield,link,http://kayakvalleyfield.org/activite/comp%C3%A9tition-de-slalom-%C2%ABla-montreal-cotton%C2%BB-%C3%A9dition-valleyfield,2016-09-12 15:20:49,3,2,1,3,0,0,0,0,0", checksum=1818077917, serialized_key_size=3, serialized_value_size=351)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=13, timestamp=1483506133969, timestamp_type=0, key=b'foo', value=b",115285708497149_1517079251651114,Bikes, Boats, & BBQ Chicken Benefit\nfor the free Franklin Falls Whitewater Park.\nSaturday August 20 2-6pm\nby the Winnipesaukee River take-out in Franklin, NH.\n\nAll donations to the non-profit are tax-deductible\n\nCornhole Tournament\nDelicious outdoor barbecued chicken\nFree music\nSponsor-A-Kid Duckie Race\nFree boat'n' bike swap\nFree canoe, kayak, and paddleboard lessons\nFree mountain bike interactive ride zone\nFarmers' Market\nFree kids' games\n\nBring your friends, bring the family, bring your paddle-buddies, bike over to Highland Mountain Bike Park, learn a hand-roll, strengthen your paddling, improve your beer-stein grip, eat a great chicken dinner, check out the plans for the new whitewater park, the free mountain bike pump track, and the new community garden!,,status,,2016-08-16 16:08:28,1,1,1,1,0,0,0,0,0", checksum=778712118, serialized_key_size=3, serialized_value_size=850)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=14, timestamp=1483506134440, timestamp_type=0, key=b'foo', value=b',115285708497149_1454420287917011,Whitewater park, Franklin, NH needs your support dammit.,A Way Back to Franklin Falls,link,https://www.indiegogo.com/projects/1775136,2016-06-23 21:03:05,7,1,0,7,0,0,0,0,0', checksum=1573664914, serialized_key_size=3, serialized_value_size=205)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=15, timestamp=1483506134854, timestamp_type=0, key=b'foo', value=b',115285708497149_1509421405750232,Will the 2020 Olympians come out of NESS?  Congratulations to the NESS juniors at Age Group Nationals!,boathousedistrict.org,link,http://boathousedistrict.org/wp-content/uploads/2016/08/USACK-AGN2016Day2FinalResults.pdf,2016-08-09 16:14:07,11,1,0,11,0,0,0,0,0', checksum=-722647214, serialized_key_size=3, serialized_value_size=293)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=16, timestamp=1483506135296, timestamp_type=0, key=b'foo', value=b',115285708497149_1509132025779170,,,status,,2016-08-09 09:50:03,2,0,0,2,0,0,0,0,0', checksum=423265360, serialized_key_size=3, serialized_value_size=81)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=17, timestamp=1483506135743, timestamp_type=0, key=b'foo', value=b",115285708497149_1502494443109595,Vintage Apple design with my custom Dark Side of the Moon paint job. $400 or I end up taking it cross country with me.  Boat is currently in Hopkinton, MA,Photos from Steve Kellett's post,photo,https://www.facebook.com/photo.php?fbid=1133740350016934&set=gm.1502494443109595&type=3,2016-08-02 19:58:38,8,11,3,6,2,0,0,0,0", checksum=-916982427, serialized_key_size=3, serialized_value_size=354)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=18, timestamp=1483506136165, timestamp_type=0, key=b'foo', value=b",115285708497149_1502985443060495,If anyone's planning ahead for cooler weather, I'm trying to find a home for a Kokatat GFED women's drysuit, size large, and the Immersion Research union suit that goes with it.  Asking $500. I'm in WRJ Vermont for the next week and a half or so. Pics here:  https://www.flickr.com/photos/historychris/,,status,,2016-08-03 09:28:06,1,0,0,1,0,0,0,0,0", checksum=-49806992, serialized_key_size=3, serialized_value_size=383)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=19, timestamp=1483506136590, timestamp_type=0, key=b'foo', value=b',115285708497149_1451595684866138,https://m.facebook.com/story.php?story_fbid=2089360004622365&id=100006451567240,,status,,2016-06-20 20:08:56,0,5,0,0,0,0,0,0,0', checksum=1151219278, serialized_key_size=3, serialized_value_size=160)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=20, timestamp=1483506137023, timestamp_type=0, key=b'foo', value=b',115285708497149_1502334703125569,,,status,,2016-08-02 15:53:02,3,0,0,3,0,0,0,0,0', checksum=-487350618, serialized_key_size=3, serialized_value_size=81)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=21, timestamp=1483506137514, timestamp_type=0, key=b'foo', value=b',115285708497149_1501413043217735,2016 Tariffville race results now posted:,Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-08-01 15:28:34,3,0,0,3,0,0,0,0,0', checksum=1703561454, serialized_key_size=3, serialized_value_size=182)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=22, timestamp=1483506137943, timestamp_type=0, key=b'foo', value=b',115285708497149_1463295913696115,,Sabine,link,http://portageurs.qc.ca/slalom-2016,2016-07-04 08:41:24,5,3,0,4,1,0,0,0,0', checksum=834514311, serialized_key_size=3, serialized_value_size=120)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=23, timestamp=1483506138371, timestamp_type=0, key=b'foo', value=b',115285708497149_1467186163307090,Winni Slalom race results posted:,Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-07-08 10:29:15,1,2,0,1,0,0,0,0,0', checksum=-597569664, serialized_key_size=3, serialized_value_size=174)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=24, timestamp=1483506138822, timestamp_type=0, key=b'foo', value=b',115285708497149_1464292726929767,During the Winni Release many thought this was fantastic. However whitewater enthusiasts are less than 30% of the total donors. \n\nA $25 donation gets you 5 free coffees from The Franklin Studio!!!\n\nGet involved! The team is working hard but projects like this take a village!,PermaCityLife,link,https://www.indiegogo.com/projects/1775136?fse_2=c&ref=gogo__fbsc__14212565,2016-07-05 11:38:12,3,0,0,3,0,0,0,0,0', checksum=1046722022, serialized_key_size=3, serialized_value_size=442)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=25, timestamp=1483506139283, timestamp_type=0, key=b'foo', value=b",115285708497149_1457872394238467,Great time at the Winni slalom. Anybody have any photos of my c2 run with Theo Stiles? I'll post more good ones that Theo took soon.,Photos from Ted Stiles's post,photo,https://www.facebook.com/photo.php?fbid=10208717629712601&set=gm.1457872394238467&type=3,2016-06-27 19:29:20,7,0,0,7,0,0,0,0,0", checksum=1633776716, serialized_key_size=3, serialized_value_size=329)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=26, timestamp=1483506139709, timestamp_type=0, key=b'foo', value=b',115285708497149_1457362394289467,Goodtimes at Winni Slalom, great course.,,status,,2016-06-27 05:38:30,13,2,0,13,0,0,0,0,0', checksum=1114063694, serialized_key_size=3, serialized_value_size=123)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=27, timestamp=1483506140135, timestamp_type=0, key=b'foo', value=b',115285708497149_1456062404419466,,,photo,https://www.facebook.com/photo.php?fbid=10101761562017635&set=gm.1456062404419466&type=3,2016-06-25 15:48:36,3,1,0,3,0,0,0,0,0', checksum=1308436504, serialized_key_size=3, serialized_value_size=168)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=28, timestamp=1483506140587, timestamp_type=0, key=b'foo', value=b',115285708497149_1456062977752742,,,photo,https://www.facebook.com/photo.php?fbid=10101761563110445&set=gm.1456062977752742&type=3,2016-06-25 15:49:59,8,0,0,8,0,0,0,0,0', checksum=133806498, serialized_key_size=3, serialized_value_size=168)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=29, timestamp=1483506141024, timestamp_type=0, key=b'foo', value=b',115285708497149_1454324997926540,Do you paddle? Yes, then help a city and future paddlers.,Outdoor New England,link,https://www.indiegogo.com/projects/1775136?ref=gogo__fblk,2016-06-23 18:28:51,6,0,0,6,0,0,0,0,0', checksum=153679724, serialized_key_size=3, serialized_value_size=212)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=30, timestamp=1483506141447, timestamp_type=0, key=b'foo', value=b',115285708497149_1446271438731896,Are the Tville race results ready for posting?  Curious about my times and gates and such.  Thanks!,,status,,2016-06-14 15:18:30,2,0,0,2,0,0,0,0,0', checksum=810922946, serialized_key_size=3, serialized_value_size=180)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=31, timestamp=1483506141888, timestamp_type=0, key=b'foo', value=b',115285708497149_1443091559049884,More Tville awards: k1w cadet,,photo,https://www.facebook.com/photo.php?fbid=10209091319262008&set=gm.1443091559049884&type=3,2016-06-10 22:07:38,7,0,0,7,0,0,0,0,0', checksum=1101812744, serialized_key_size=3, serialized_value_size=197)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=32, timestamp=1483506142336, timestamp_type=0, key=b'foo', value=b',115285708497149_1443090419049998,Tariffville section C gate judges, session A,,photo,https://www.facebook.com/photo.php?fbid=10209091305301659&set=gm.1443090419049998&type=3,2016-06-10 22:05:28,4,0,0,4,0,0,0,0,0', checksum=-480387558, serialized_key_size=3, serialized_value_size=212)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=33, timestamp=1483506142801, timestamp_type=0, key=b'foo', value=b',115285708497149_1441024605923246,After I posted about the Northeast Regional Team, I learned that there is not going to be a regional team training camp this year.  The national team coaches are concentrating on the Olympics and racing in Europe and there is no funding for it.  In a last ditch effort to keep it going, I asked the Nantahala Racing Club if they could organize it, but they declined.  So, there is no regional team training camp this year.  Apologies to anyone who went to the races thinking they could qualify for the team.  On the other hand, I am going to take a couple of kids to Charlotte to train the week before Junior Olympics at NOC, July 23-30.  So, if you are interested in going to Charlotte and paddling there that week, then going to Junior Olympics at NOC, contact me.  It is too far for us to go to Charlotte on weekends, so hot crowded summer is the best time for us to go.  Without sufficient practice at Charlotte, it is impossible to race there.  If you are interested, contact me: rlugbill@gmail.com. - Ron Lugbill,,status,,2016-06-08 15:39:16,3,0,0,3,0,0,0,0,0', checksum=416086119, serialized_key_size=3, serialized_value_size=1099)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=34, timestamp=1483506143262, timestamp_type=0, key=b'foo', value=b',115285708497149_1440875132604860,If you are at Tville please keep your eyes peeld for a pair of eye glasses at the dead end parking area.  They disapeared Sunday afternoon after the slalom race during the rainstorm.,,status,,2016-06-08 11:30:44,0,1,0,0,0,0,0,0,0', checksum=-1704716081, serialized_key_size=3, serialized_value_size=263)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=35, timestamp=1483506143693, timestamp_type=0, key=b'foo', value=b",115285708497149_1437828012909572,Awards photos from Tville! Thanks for a great race!!,Photos from Barrett Phillips's post,photo,https://www.facebook.com/photo.php?fbid=10100320609383080&set=gm.1437828012909572&type=3,2016-06-05 17:19:27,17,1,0,17,0,0,0,0,0", checksum=-924988942, serialized_key_size=3, serialized_value_size=257)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=36, timestamp=1483506144147, timestamp_type=0, key=b'foo', value=b',115285708497149_1436803713012002,Apologies for not getting over to T-ville to help out this weekend. Work-work has reared its ugly head and I am now on deadline. Maybe in July for the Triple ....,,status,,2016-06-04 09:50:44,2,0,0,2,0,0,0,0,0', checksum=1424815813, serialized_key_size=3, serialized_value_size=243)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=37, timestamp=1483506144606, timestamp_type=0, key=b'foo', value=b",115285708497149_1436158033076570,Almost done!,Photos from Amy Sullivan's post,photo,https://www.facebook.com/photo.php?fbid=10209102310585550&set=gm.1436158033076570&type=3,2016-06-03 12:30:19,5,1,0,5,0,0,0,0,0", checksum=-831850661, serialized_key_size=3, serialized_value_size=211)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=38, timestamp=1483506145067, timestamp_type=0, key=b'foo', value=b',115285708497149_1435627946462912,Again, anyone who wants to hang gates with Gary V. Grosclaude and me.  We will be there at 9:15 ish.  Looking forward to rivers edge work.,,status,,2016-06-02 21:42:09,2,4,0,2,0,0,0,0,0', checksum=372306255, serialized_key_size=3, serialized_value_size=219)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=39, timestamp=1483506145496, timestamp_type=0, key=b'foo', value=b',115285708497149_1435102176515489,The Mill is a sponsor for the N.E.S.S race at Tariffville Gorge.,,photo,https://www.facebook.com/photo.php?fbid=10209093007192971&set=gm.1435102176515489&type=3,2016-06-02 06:53:24,16,6,0,16,0,0,0,0,0', checksum=-1944113631, serialized_key_size=3, serialized_value_size=234)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=40, timestamp=1483506145935, timestamp_type=0, key=b'foo', value=b',115285708497149_1435109329848107,http://tangentindinc.com\nTangent Industries, is also a sponsor for the New England Slalom Series race at T-Ville.,Tangent Industries Inc. -- Light Curable Chemistry | Light Curing Chemistry,link,http://tangentindinc.com/,2016-06-02 07:05:19,6,0,0,6,0,0,0,0,0', checksum=-1955001519, serialized_key_size=3, serialized_value_size=292)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=41, timestamp=1483506146368, timestamp_type=0, key=b'foo', value=b',115285708497149_1435106826515024,amy-grosclaude.squarespace.com/ \nIs a sponsor for the N.E.S.S race at Tariffville Gorge.,Work,link,http://amy-grosclaude.squarespace.com/,2016-06-02 07:01:09,4,0,0,4,0,0,0,0,0', checksum=1405686033, serialized_key_size=3, serialized_value_size=209)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=42, timestamp=1483506146794, timestamp_type=0, key=b'foo', value=b',115285708497149_1435098103182563,www.painesinc.com/       \nPaines, Inc.  Is a sponsor for the  N.E.S.S  T-Ville race!,Paines, Inc., Recycling & Disposal Services - serving the needs of people, businesses, and...,link,http://www.painesinc.com/,2016-06-02 06:43:43,6,0,0,6,0,0,0,0,0', checksum=146286770, serialized_key_size=3, serialized_value_size=281)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=43, timestamp=1483506147222, timestamp_type=0, key=b'foo', value=b',115285708497149_1433547666670940,I am the Northeast Team Coordinator for the national junior team training camp at Nantahala Outdoor Center at the end of July.  Each region of the country has a team that can go to the training camp right before the Junior Olympics.  You have to race at least 3 NESS races to qualify and you have to be under 16 as of January 1, 2016.  Please let me know if you are interested and what your date of birth is.  I can figure out who qualifies based on race results if I know your date of birth.  There are under 16 and under 14 and under 12 categories for each closed boat class.  There may be some money available to help pay your expenses if you are on the northeast regional team.  Please notify me if you are interested or have questions and let me know your age and date of birth.  Ron Lugbill,,status,,2016-05-31 11:38:00,4,4,0,4,0,0,0,0,0', checksum=443005209, serialized_key_size=3, serialized_value_size=877)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=44, timestamp=1483506147665, timestamp_type=0, key=b'foo', value=b',115285708497149_1433543720004668,Come Race in the Tariffville Whitewater Slalom this Sunday, June 5th 2016!  Open Unlimited Gate Practice on Saturday.  Free Coaching from Many Experienced Slalom Racers & Former US Team Members.  Free Camping is available behind The Mill, 2 Tunxis Road, Tariffville, CT. Restrooms & Hot Showers available in The Mill. We are looking for volunteers to help with course hanging Wednsday, Thursday & Friday with the goal of the course being finished Friday.  If you are interested in Slalom Race Organization we are also willing to teach the black arts to you.\nWeather Forecast is 80 Degrees + for Saturday & Sunday.\n,Tariffville Slalom \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/tariffville-slalom/,2016-05-31 11:31:19,8,5,0,7,1,0,0,0,0', checksum=-1363825828, serialized_key_size=3, serialized_value_size=767)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=45, timestamp=1483506148099, timestamp_type=0, key=b'foo', value=b",115285708497149_1433486863343687,If ever you desperately need to paddle along some gates on July 9-10th, we have an event in Valleyfield. It's way, way up north. Actually, it's close to Montreal, Qc. It's a single blade event, it's a friendly race and for some of you, it may be a different place to paddle! The website is in french. Hopefully, we will get the translation soon. But, do not hesitate to ask me questions if you are interested in coming to see us. :-)\n,Comp\xc3\xa9tition de slalom 2016 | Club de Canot-Camping et d'eau-vive Les Portageurs,link,http://portageurs.qc.ca/slalom-2016,2016-05-31 10:02:03,7,4,0,7,0,0,0,0,0", checksum=491031068, serialized_key_size=3, serialized_value_size=628)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=46, timestamp=1483506148544, timestamp_type=0, key=b'foo', value=b',115285708497149_1433104116715295,Covered Bridge race results are now posted :-),Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-05-30 20:31:38,1,0,0,1,0,0,0,0,0', checksum=119364718, serialized_key_size=3, serialized_value_size=187)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=47, timestamp=1483506148966, timestamp_type=0, key=b'foo', value=b',115285708497149_1432015200157520,Nice Article on Devin McEwan in the Hartford Courant Newspaper. Featuring Sandy Boynton & Casey Eichfeld\n\nOlympic Slalom Canoeing Flows From Father To Son\n\nhttp://www.courant.com/sports/hc-riley-column-0529-20160528-column.html,,status,,2016-05-29 12:09:08,9,0,1,9,0,0,0,0,0', checksum=1067078935, serialized_key_size=3, serialized_value_size=308)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=48, timestamp=1483506149400, timestamp_type=0, key=b'foo', value=b',115285708497149_1424280804264293,FS- low volume C2.  great for kids, adults maybe up to 130 lbs?   $150.,Ted,photo,https://www.facebook.com/photo.php?fbid=10208406776941476&set=gm.659532010870245&type=3,2016-05-19 21:15:29,2,1,0,2,0,0,0,0,0', checksum=1746602681, serialized_key_size=3, serialized_value_size=241)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=49, timestamp=1483506149838, timestamp_type=0, key=b'foo', value=b',115285708497149_1423091967716510,Millbrook Schacho for sale.  Regular layup with Esquif double straps and Gaia airbags. Boat has only been used twice and is in excellent condition, as are the bags.  Will be travelingfrom PA to VT on or about June 10, so I could deliver to New England. Asking $1,200.  Located in Bethlehem, PA.  Pics here:  ,Chris,link,https://www.flickr.com/photos/historychris/,2016-05-18 09:31:56,1,1,0,1,0,0,0,0,0', checksum=443761515, serialized_key_size=3, serialized_value_size=435)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=50, timestamp=1483506150288, timestamp_type=0, key=b'foo', value=b',115285708497149_1422728531086187,Fiddlehead race results are now posted :-),Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-05-17 22:06:46,5,0,0,5,0,0,0,0,0', checksum=41100096, serialized_key_size=3, serialized_value_size=183)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=51, timestamp=1483506150695, timestamp_type=0, key=b'foo', value=b',115285708497149_1422429444449429,Yves Prigent Demonstrating Flatwater Slalom Drills Developed with Jean Yves Prigent & Guillaume de Fierville.\n\n,Kayak Slalom Eau Calme,video,https://vimeo.com/166837122,2016-05-17 13:17:50,2,0,0,2,0,0,0,0,0', checksum=1797634461, serialized_key_size=3, serialized_value_size=240)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=52, timestamp=1483506151140, timestamp_type=0, key=b'foo', value=b",115285708497149_1422203854471988,I'm attempting to help a neighbor unload a couple of boats.  He's a motivated seller- asking $140 each for the Perception Reflex slalom boat and the Pirouette S river runner.  Call him at 802 431 3503 (Jaime and Trina).  the boats are in Rochester, VT.,,photo,https://www.facebook.com/photo.php?fbid=10208911415610170&set=gm.1422203854471988&type=3,2016-05-17 07:31:34,0,0,0,0,0,0,0,0,0", checksum=-239470080, serialized_key_size=3, serialized_value_size=420)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=53, timestamp=1483506151565, timestamp_type=0, key=b'foo', value=b',115285708497149_1413683428657364,Fiddlehead soup will be on Saturday, course is up, come have fun, all are welcomed.,,status,,2016-05-06 21:00:48,5,5,0,5,0,0,0,0,0', checksum=-618285496, serialized_key_size=3, serialized_value_size=164)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=54, timestamp=1483506152028, timestamp_type=0, key=b'foo', value=b",115285708497149_1421083217917385,Valleyfield Quebec Cup slalom June 18 - at least, I think it is the 18th. It's also the second leg of their paddling triathlon, which is normally on the Saturday afternoon (following a 10km flatwater race on the nearby canal - a nice cross-training opportunity).,Paddling Triathlon/Coupe du Qu\xc3\xa9bec | Centre d'excellence d'eau vive de Valleyfield,link,http://kayakvalleyfield.org/activite/paddling-triathloncoupe-du-qu\xc3\xa9bec,2016-05-15 20:32:36,6,5,0,6,0,0,0,0,0", checksum=-1881542491, serialized_key_size=3, serialized_value_size=495)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=55, timestamp=1483506152463, timestamp_type=0, key=b'foo', value=b",115285708497149_1421579931201047,There's a couple of us heading up to train at Valleyfield (in Canada) on Saturday the 21st. We're leaving from Burlington, VT in the morning. Message me if interested.,,status,,2016-05-16 11:22:48,5,0,0,5,0,0,0,0,0", checksum=1603091680, serialized_key_size=3, serialized_value_size=248)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=56, timestamp=1483506152919, timestamp_type=0, key=b'foo', value=b',115285708497149_1419156301443410,Will there be a potluck dinner Saturday evening at Covered Bridge?,,status,,2016-05-13 15:26:20,3,2,0,3,0,0,0,0,0', checksum=165993782, serialized_key_size=3, serialized_value_size=147)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=57, timestamp=1483506153351, timestamp_type=0, key=b'foo', value=b',115285708497149_1416250561733984,Fiddlehead Canoe/Kayak Slalom \nThe winner of the NESS raffle is Ian Wicenski, Congradution Ian.\n.\nThank you everyone for coming to the Fiddlehead Slalom, and special thanks and appreciation to those who step up and offer to help to the very end, the  New England Slalom paddling community is the best. Results are coming.,,status,,2016-05-09 22:38:46,6,1,0,6,0,0,0,0,0', checksum=-1725012886, serialized_key_size=3, serialized_value_size=402)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=58, timestamp=1483506153773, timestamp_type=0, key=b'foo', value=b',115285708497149_1416039125088461,FYI,pbs.twimg.com,link,https://pbs.twimg.com/media/CiB13xPW0AAPdmR.jpg,2016-05-09 15:46:49,6,0,0,0,0,2,0,4,0', checksum=628948166, serialized_key_size=3, serialized_value_size=142)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=59, timestamp=1483506154203, timestamp_type=0, key=b'foo', value=b',115285708497149_1415832008442506,Blackwater race results are now posted :-),Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-05-09 11:06:28,1,1,0,1,0,0,0,0,0', checksum=907653519, serialized_key_size=3, serialized_value_size=183)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=60, timestamp=1483506154632, timestamp_type=0, key=b'foo', value=b',115285708497149_1415703361788704,,,status,,2016-05-09 08:27:35,6,0,0,6,0,0,0,0,0', checksum=-2030938379, serialized_key_size=3, serialized_value_size=81)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=61, timestamp=1483506155064, timestamp_type=0, key=b'foo', value=b',115285708497149_1414788411880199,http://siwihome.azurewebsites.net/canoe123/live?SessionKey=elokken.20160507,,status,,2016-05-08 07:36:07,2,2,0,2,0,0,0,0,0', checksum=-1574139437, serialized_key_size=3, serialized_value_size=156)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=62, timestamp=1483506155494, timestamp_type=0, key=b'foo', value=b',115285708497149_1407009279324779,top of blackwater course,Blackwater Slalom gates 1 thru 14,video,https://www.youtube.com/watch?v=3wPA7KKEau8,2016-04-28 13:56:39,4,8,0,4,0,0,0,0,0', checksum=868138857, serialized_key_size=3, serialized_value_size=180)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=63, timestamp=1483506155922, timestamp_type=0, key=b'foo', value=b",115285708497149_1412753315417042,When will the blackwater results be posted?  I wasn't able to see all of my times at the race. Thanks!,,status,,2016-05-05 17:59:35,0,8,0,0,0,0,0,0,0", checksum=-1267982797, serialized_key_size=3, serialized_value_size=183)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=64, timestamp=1483506156365, timestamp_type=0, key=b'foo', value=b',115285708497149_1411891495503224,Todays a good day to Register,\n\n,Fiddlehead Slalom \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/fiddlehead-slalom/,2016-05-04 14:16:35,2,2,0,2,0,0,0,0,0', checksum=251647538, serialized_key_size=3, serialized_value_size=183)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=65, timestamp=1483506156799, timestamp_type=0, key=b'foo', value=b",115285708497149_1412735982085442,https://www.facebook.com/jessfox.canoeslalom/posts/1140014726020867,The Best Two Minute Video Of An Olympian Training You'll See All Year. Promise.,link,http://www.huffingtonpost.com.au/2016/05/05/jess-fox-training-video_n_9835324.html,2016-05-05 17:22:27,0,0,0,0,0,0,0,0,0", checksum=-1368721260, serialized_key_size=3, serialized_value_size=307)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=66, timestamp=1483506157234, timestamp_type=0, key=b'foo', value=b',115285708497149_1410902718935435,Kenduskeag race results posted:,Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-05-03 08:16:04,1,3,0,1,0,0,0,0,0', checksum=1168371777, serialized_key_size=3, serialized_value_size=172)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=67, timestamp=1483506157671, timestamp_type=0, key=b'foo', value=b',115285708497149_1407693199256387,Hi everyone,   The Fiddlehead Slalom is all set, release scheduled, first and only registration recieved, Thank You Pratt family, look forward to seeing everyone.  Race Organ singing his song,,status,,2016-04-29 08:45:52,4,2,1,4,0,0,0,0,0', checksum=1861945202, serialized_key_size=3, serialized_value_size=272)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=68, timestamp=1483506158181, timestamp_type=0, key=b'foo', value=b',115285708497149_1407101139315593,Follow and tag your friends and nemesis on Instagram,,photo,https://www.facebook.com/photo.php?fbid=10101694059947325&set=gm.1407101139315593&type=3,2016-04-28 16:18:07,2,0,0,2,0,0,0,0,0', checksum=-1542064179, serialized_key_size=3, serialized_value_size=220)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=69, timestamp=1483506158673, timestamp_type=0, key=b'foo', value=b',115285708497149_1407014479324259,who dat?,Bob to Gate 1 Blackwater Slalom,video,https://www.youtube.com/watch?v=xKCLWTQoEmA,2016-04-28 14:05:39,2,0,0,2,0,0,0,0,0', checksum=2116321625, serialized_key_size=3, serialized_value_size=162)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=70, timestamp=1483506159184, timestamp_type=0, key=b'foo', value=b',115285708497149_1407014235990950,who dat?,Steve - Blackwater Slalom to Gate 1,video,https://www.youtube.com/watch?v=MyNuJ_1QWhw,2016-04-28 14:05:19,2,0,0,2,0,0,0,0,0', checksum=-1250534524, serialized_key_size=3, serialized_value_size=166)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=71, timestamp=1483506159623, timestamp_type=0, key=b'foo', value=b',115285708497149_1407014029324304,Who Dat?,Clayton to Gate 1 Blackwater Slalom,video,https://www.youtube.com/watch?v=vayF2kLeq1g,2016-04-28 14:04:59,2,0,0,2,0,0,0,0,0', checksum=-1396216938, serialized_key_size=3, serialized_value_size=166)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=72, timestamp=1483506160038, timestamp_type=0, key=b'foo', value=b',115285708497149_1405287256163648,Such a fun weekend!  Thanks to everyone who helped me figure out the rules for my first race(s). If anyone has a used skirt, sm/med tunnel for a k1, I need one for my new to me barcelona. Thanks!,,status,,2016-04-26 13:07:13,7,0,0,7,0,0,0,0,0', checksum=1381743613, serialized_key_size=3, serialized_value_size=276)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=73, timestamp=1483506160473, timestamp_type=0, key=b'foo', value=b',115285708497149_1403638332995207,I am the Northeast Region Coordinator for the Regional Team for junior and cadet racers.  If you are interested in this, you can contact me at rlugbill@gmail.com and/or go to this site:  ,WhitewaterSlalom.us - Regional Teams,link,http://www.whitewaterslalom.us/clubs/articles/regional-teams.html,2016-04-24 14:55:54,3,0,0,3,0,0,0,0,0', checksum=1707111670, serialized_key_size=3, serialized_value_size=367)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=74, timestamp=1483506160894, timestamp_type=0, key=b'foo', value=b",115285708497149_1395996137092760,Adam Van Grack named as interim Chair of the USACK Board of Directors\n\nBY AARON MANN | APRIL 15, 2016, 1:44 P.M. (ET)\nUSA Canoe/Kayak would like to extend a warm welcome to its new interim Chair of the Board of Directors, Adam Van Grack. As Chair, Mr. Van Grack will be working closely with USA Canoe/Kayak's shared CEO, Wade Blackwood, on accomplishing all of the organization's goals for 2016 and beyond.   \n\nDuring last night's meeting, the USA Canoe/Kayak Board collectively expressed its thanks and gratitude to outgoing Chair, Bob Lally. Mr. Lally had served as the Chair of the USA Canoe/Kayak Board of Directors since 2011.,,status,,2016-04-15 15:19:16,3,0,0,3,0,0,0,0,0", checksum=1612800896, serialized_key_size=3, serialized_value_size=712)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=75, timestamp=1483506161349, timestamp_type=0, key=b'foo', value=b',115285708497149_1395975817094792,They have it done!! The Vector Wero whitewater course in Auckland is running. Get ready, more pushups, more attainments, and maybe new gear too. I am going to contact a couple manufacturers about getting USA Masters gear for World Masters Games next year. I am thinking about connected short or long sleeve paddle jacket/skirts. Maybe helmets. Maybe separate jackets and skirts.\nIf you are planning on accepting this challenge, let me know if you would like to order paddling gear. We would need to know how many units, make a design and get the process going soon.\nTrain hard, train smart.,Vector Wero Whitewater Park,link,https://www.tvnz.co.nz/one-news/sport/other/nz-canoe-slalom-competitors-give-new-wero-white-water-facility-thumbs-up?autoPlay=4846844119001,2016-04-15 14:52:35,0,0,0,0,0,0,0,0,0', checksum=-1179850794, serialized_key_size=3, serialized_value_size=835)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=76, timestamp=1483506161797, timestamp_type=0, key=b'foo', value=b",115285708497149_1393648813994159,To: Bob Lally; robertlally@msn.com, Rick Reed; Rick.reed@informa.com, France Jacot; France@brainyfrog.com, Mike Knopp; mknopp@okcbf.org, Anna Minto; Aminto@trchange.com, Peter Newton; pnewton@rei.com, \nRichard Perlmutter; RPerlmutter@foulgerpratt.com, Scott Shipley; scott@s2odesign.com, Bob Balk; bobbalk@yahoo.com, Adam Van Grack; vangrack@gmail.com, Scott Mann; Scottiemann@gmail.com, Ariel Farrar-Wellman; Afarrwel@gmail.com, Robert Pennington; Rbpennington@hotmail.com\n\nDear USACK Board Members Past & Present,\n\nOver the last 5 days more than 210 individuals have written letters or signed a petition supporting the merger of USACK and the ACA. Bill Endicott and I produced and distributed this petition to engage, inform and survey the opinions of members from a wide range of paddling disciplines under the aegis of USACK. The signers include past and current Olympians, junior, U23 & senior team members, coaches, volunteers, judges, race organizers, parents of athletes as well as leaders in Paddle Sports. These Paddle Sports enthusiasts wrote letters and signed the petition in an effort to help you, the USACK Board of Directors, understand the widespread support by your constituents for the merger between USACK and the ACA.  Attached are a sampling of the letters and petitions for your review as well as a link to the complete (and rapidly growing) repository of the signed documents.  The petition is inline below.\n\nI urge you to consider the learned opinions of your constituents in Paddle Sports when making important decisions that affect the future of our sport.\n\nBest Regards, \n\nBill Hearn - ACA Member, USACK Member, Former Freestyle, Slalom & Wildwater National Team Member, Gate Judge & Race Organizer.  E: billhearnc1@gmail.com  C: (978) 340-7181\n\nLink to Signed Letters & Petitions; https://drive.google.com/open?id=0Bwcna0x2X-FFQnctTl9IMkgxYUk\n\nThursday, April 07, 2016\n\nWe Believe a Merger of USACK with the ACA is the Best Path Forward for PaddleSports in the USA. \n\nCompetitive and Recreational PaddleSports Will Benefit from Cooperation, Shared Resources and Increased Membership.\n\nA Unified American PaddleSports Organization Will Appeal to Potential New Members, Sponsors, Cooperating Non-Profits and Will Be Influential with Media, Legislators and the USOC \n\nA Merger Makes Sense Because it Will Reconnect Us To The Base Of Our Sport, Introducing Thousands of Kids and Families to PaddleSports.   We Believe That Connecting with the Base Is Vital to Recruit and Develop Successful Athletes. \n\nThe ACA Estimates that 1,000 of Its' 8,000 Instructors Want to Add Coaching of Elementary Slalom and Sprint to Their Repertoire.  The ACA is Funding and Promoting the Racer Quest Program, A \xc2\xbd Day Introduction to Slalom and Sprint Paddling for Kids.  Racer Quest was Introduced at the ACA Instructor-Trainer Conference in October 2015 and Received a Very Favorable Reception.  To Build On the Success of Racer Quest the ACA is Funding & Developing a Complete Coaching Curriculum from the Elementary Level to National Team Coach.  \nThe Racer Quest Program Can Be Expanded to Include All Facets of Competitive PaddleSports.\n\nDespite USACK's Best Efforts - a Reduction in USOC Funding, the Tough Economy & a Small Member Base has Resulted in Unprecedented Challenges for Competitive PaddleSports in the USA.  \n\nIt's Time To Take Action and Merge With the ACA!\n\nPlease Add Your Signature to Mine and Support The Future Of PaddleSports;\n \nBill Endicott, US Slalom & Wildwater Team 1971 & 1973, US Slalom Coach, 1977-1993, US Olympic coach 1992 & US Olympic Team Leader 2004, World Paddle Awards Lifetime Achievement Award.\n    Name      Signature Email                  Date\n1_______________               |            _          |                 __ @_____ ___.com |_    _/__  _/16\n ...
# hi
# ConsumerRecord(topic='test2', partition=0, offset=77, timestamp=1483506162250, timestamp_type=0, key=b'foo', value=b",115285708497149_1392700437422330,Hi all - Please take a look at the petition and fact sheet in the link below.  Would you be interested in signing and distributing a petition in favor of merging the ACA & USACK?\nLink; https://drive.google.com/file/d/0Bwcna0x2X-FFZS0xQTdzN19vWUU/view\nThis is time sensitive because USACK has a pivotal Board of Directors meeting tomorrow (Tuesday April 12th 2016) and it's important to demonstrate popular support for the merger if you support it.\nPlease sign and scan / take a photo and return by text, email or FB Messenger. E: billhearnc1@gmail.comC: (978) 340-7181\n\nBill Endicott wrote up this petition in favor of merging USACK (USA Canoe Kayak) and the ACA (American Canoe Association).  USACK is currently $160K in the red, ACA has been running operations for USACK since last year.  All of our Whitewater Slalom Olympic & National Team athletes & coaches signed this petition at the Olympic Trials last weekend along with ~150 other members, parents, volunteers as well as former Olympians & US Team Members.  A merger will increase the membership of our NGB (National Governing Body for paddlesports with the US Olympic Committee) from ~800 members to more than 35K members and give us a unified PaddleSports organization with the influence to support our athletes in the Rio Olympics as well as underserved paddlesports like Freestyle, Extreme Racing, SUP, Wildwater, Canoe Polo, Marathon as well as support recreational paddlesports.,,status,,2016-04-11 16:05:05,1,1,2,1,0,0,0,0,0", checksum=-1864891219, serialized_key_size=3, serialized_value_size=1525)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=78, timestamp=1483506162670, timestamp_type=0, key=b'foo', value=b",115285708497149_1380562818636092,Interesting Sections of USACK Bylaws;\n\nSection 7.9. Tenure and Term Limits\n\nThe term of office for a director of the Board of Directors will generally be four (4) years subject to the exceptions described herein. A director shall hold office until the director's successor is elected and qualified, or until the director's earlier resignation, removal, incapacity, disability or death. No director of the Board of Directors shall serve more than two (2) consecutive terms. For the initial Board, a term of one half (1/2) the maximum allowed shall constitute a full term. Thus, an individual selected for a two (2) year term shall be eligible to serve only one (1) additional four (4) year term immediately following the two (2) year term in a system with a four (4) year term limit. A Director who has served two (2) consecutive terms will not be eligible to serve again until four (4) years have elapsed.\n\nWhen a director is elected/selected to fill a vacancy for a period of two (2) years or more because of the resignation, removal, incapacity, disability or death of a director their service shall constitute a full term. Thus, if the vacancy being filled is for two (2) or more years, and the maximum term is four (4) years, the director may serve one additional four (4) year term following completion of the filed vacancy term. If the vacancy being filled is for less than one half (1/2) the maximum term, the term shall not be a full term and the director shall be able to serve two (2) additional full terms following completion of the filled vacancy term.,,status,,2016-03-29 19:43:45,1,3,0,0,0,1,0,0,0", checksum=1956049395, serialized_key_size=3, serialized_value_size=1646)
# hi
# ...
# hi
# ConsumerRecord(topic='test2', partition=0, offset=411, timestamp=1483508595241, timestamp_type=0, key=b'foo', value=b",115285708497149_1578969142128791,Farmington Slalom (Oct 15-16)\nI've been talking to several people who are connected with managing the Farmington watershed, have studied historical flows, made calculations, gotten on the ground reports from helpful folks as well as Bob the dam keeper (who is super helpful!).  I'm still not completely sure, but I'm hopeful we can have the race.  I currently estimate the chance of the race running are 75%.  I'll update as I get more comfortable with the projections.  I'm giving myself until next Monday end of day and hoping to know before that.,,status,,2016-10-05 19:28:52,10,1,1,10,0,0,0,0,0", checksum=-2016079670, serialized_key_size=3, serialized_value_size=632)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=412, timestamp=1483508595659, timestamp_type=0, key=b'foo', value=b",115285708497149_1562305680461804,Valleyfield race Sept 24th and 25th! ,Comp\xc3\xa9tition de slalom \xc2\xabLa Montreal Cotton\xc2\xbb - \xc3\x89dition Valleyfield | Centre d'excellence d'eau vive de Valleyfield,link,http://kayakvalleyfield.org/activite/comp%C3%A9tition-de-slalom-%C2%ABla-montreal-cotton%C2%BB-%C3%A9dition-valleyfield,2016-09-22 14:47:53,6,0,0,6,0,0,0,0,0", checksum=-962491463, serialized_key_size=3, serialized_value_size=351)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=413, timestamp=1483508596110, timestamp_type=0, key=b'foo', value=b",115285708497149_1424715654220808,Congratulations to Ashley Nee, Devin McEwan , Casey Eichfeld & Michal Smolen and to all the coaches, parents, paddlers, volunteers and employees of USACK & ACA. The USA will send a full Whitewater Slalom Team to the Rio Olympics. Rafal Smolen (Michal Smolen's Dad) & Silvan Pobraj are the Olympic coaches.   The International Canoe Federation has assigned Olympic Slots to the USA for K1W and C2. Ashley, Devin & Casey qualified the Olympic spots for the USA with their performances at international races in 2015 and qualified for the US Team at Team Trials races in Charlotte, NC & OKC this spring. Casey had already locked down an Olympic spot in C1 so he was already counted as a warm body in the US Olympic delegation. The only remaining question was what Olympic spots other countries would claim and a bit of politics and procedure to verify that the USA could send a K1W and a C2.,,status,,2016-05-20 10:54:09,15,1,1,15,0,0,0,0,0", checksum=-1663816718, serialized_key_size=3, serialized_value_size=971)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=414, timestamp=1483508596535, timestamp_type=0, key=b'foo', value=b",115285708497149_1550774144948291,Valleyfield race Sept 24th and 25th! ,Comp\xc3\xa9tition de slalom \xc2\xabLa Montreal Cotton\xc2\xbb - \xc3\x89dition Valleyfield | Centre d'excellence d'eau vive de Valleyfield,link,http://kayakvalleyfield.org/activite/comp%C3%A9tition-de-slalom-%C2%ABla-montreal-cotton%C2%BB-%C3%A9dition-valleyfield,2016-09-12 15:20:49,3,2,1,3,0,0,0,0,0", checksum=1876583458, serialized_key_size=3, serialized_value_size=351)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=415, timestamp=1483508596952, timestamp_type=0, key=b'foo', value=b",115285708497149_1517079251651114,Bikes, Boats, & BBQ Chicken Benefit\nfor the free Franklin Falls Whitewater Park.\nSaturday August 20 2-6pm\nby the Winnipesaukee River take-out in Franklin, NH.\n\nAll donations to the non-profit are tax-deductible\n\nCornhole Tournament\nDelicious outdoor barbecued chicken\nFree music\nSponsor-A-Kid Duckie Race\nFree boat'n' bike swap\nFree canoe, kayak, and paddleboard lessons\nFree mountain bike interactive ride zone\nFarmers' Market\nFree kids' games\n\nBring your friends, bring the family, bring your paddle-buddies, bike over to Highland Mountain Bike Park, learn a hand-roll, strengthen your paddling, improve your beer-stein grip, eat a great chicken dinner, check out the plans for the new whitewater park, the free mountain bike pump track, and the new community garden!,,status,,2016-08-16 16:08:28,1,1,1,1,0,0,0,0,0", checksum=1986535525, serialized_key_size=3, serialized_value_size=850)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=416, timestamp=1483508597382, timestamp_type=0, key=b'foo', value=b',115285708497149_1454420287917011,Whitewater park, Franklin, NH needs your support dammit.,A Way Back to Franklin Falls,link,https://www.indiegogo.com/projects/1775136,2016-06-23 21:03:05,7,1,0,7,0,0,0,0,0', checksum=-1141337400, serialized_key_size=3, serialized_value_size=205)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=417, timestamp=1483508597809, timestamp_type=0, key=b'foo', value=b',115285708497149_1509421405750232,Will the 2020 Olympians come out of NESS?  Congratulations to the NESS juniors at Age Group Nationals!,boathousedistrict.org,link,http://boathousedistrict.org/wp-content/uploads/2016/08/USACK-AGN2016Day2FinalResults.pdf,2016-08-09 16:14:07,11,1,0,11,0,0,0,0,0', checksum=1531523205, serialized_key_size=3, serialized_value_size=293)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=418, timestamp=1483508598234, timestamp_type=0, key=b'foo', value=b',115285708497149_1509132025779170,,,status,,2016-08-09 09:50:03,2,0,0,2,0,0,0,0,0', checksum=-36097257, serialized_key_size=3, serialized_value_size=81)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=419, timestamp=1483508598686, timestamp_type=0, key=b'foo', value=b",115285708497149_1502494443109595,Vintage Apple design with my custom Dark Side of the Moon paint job. $400 or I end up taking it cross country with me.  Boat is currently in Hopkinton, MA,Photos from Steve Kellett's post,photo,https://www.facebook.com/photo.php?fbid=1133740350016934&set=gm.1502494443109595&type=3,2016-08-02 19:58:38,8,11,3,6,2,0,0,0,0", checksum=1504065625, serialized_key_size=3, serialized_value_size=354)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=420, timestamp=1483508599111, timestamp_type=0, key=b'foo', value=b",115285708497149_1502985443060495,If anyone's planning ahead for cooler weather, I'm trying to find a home for a Kokatat GFED women's drysuit, size large, and the Immersion Research union suit that goes with it.  Asking $500. I'm in WRJ Vermont for the next week and a half or so. Pics here:  https://www.flickr.com/photos/historychris/,,status,,2016-08-03 09:28:06,1,0,0,1,0,0,0,0,0", checksum=-1051536322, serialized_key_size=3, serialized_value_size=383)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=421, timestamp=1483508599557, timestamp_type=0, key=b'foo', value=b',115285708497149_1451595684866138,https://m.facebook.com/story.php?story_fbid=2089360004622365&id=100006451567240,,status,,2016-06-20 20:08:56,0,5,0,0,0,0,0,0,0', checksum=-1306621716, serialized_key_size=3, serialized_value_size=160)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=422, timestamp=1483508599993, timestamp_type=0, key=b'foo', value=b',115285708497149_1502334703125569,,,status,,2016-08-02 15:53:02,3,0,0,3,0,0,0,0,0', checksum=-2105247639, serialized_key_size=3, serialized_value_size=81)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=423, timestamp=1483508600443, timestamp_type=0, key=b'foo', value=b',115285708497149_1501413043217735,2016 Tariffville race results now posted:,Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-08-01 15:28:34,3,0,0,3,0,0,0,0,0', checksum=-1771678809, serialized_key_size=3, serialized_value_size=182)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=424, timestamp=1483508600897, timestamp_type=0, key=b'foo', value=b',115285708497149_1463295913696115,,Sabine,link,http://portageurs.qc.ca/slalom-2016,2016-07-04 08:41:24,5,3,0,4,1,0,0,0,0', checksum=-129109195, serialized_key_size=3, serialized_value_size=120)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=425, timestamp=1483508601329, timestamp_type=0, key=b'foo', value=b',115285708497149_1467186163307090,Winni Slalom race results posted:,Race Results \xe2\x80\x93 NESSRACE.COM,link,http://nessrace.com/race-results/,2016-07-08 10:29:15,1,2,0,1,0,0,0,0,0', checksum=873415591, serialized_key_size=3, serialized_value_size=174)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=426, timestamp=1483508601754, timestamp_type=0, key=b'foo', value=b',115285708497149_1464292726929767,During the Winni Release many thought this was fantastic. However whitewater enthusiasts are less than 30% of the total donors. \n\nA $25 donation gets you 5 free coffees from The Franklin Studio!!!\n\nGet involved! The team is working hard but projects like this take a village!,PermaCityLife,link,https://www.indiegogo.com/projects/1775136?fse_2=c&ref=gogo__fbsc__14212565,2016-07-05 11:38:12,3,0,0,3,0,0,0,0,0', checksum=-717885976, serialized_key_size=3, serialized_value_size=442)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=427, timestamp=1483508602199, timestamp_type=0, key=b'foo', value=b",115285708497149_1457872394238467,Great time at the Winni slalom. Anybody have any photos of my c2 run with Theo Stiles? I'll post more good ones that Theo took soon.,Photos from Ted Stiles's post,photo,https://www.facebook.com/photo.php?fbid=10208717629712601&set=gm.1457872394238467&type=3,2016-06-27 19:29:20,7,0,0,7,0,0,0,0,0", checksum=1313690026, serialized_key_size=3, serialized_value_size=329)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=428, timestamp=1483508602641, timestamp_type=0, key=b'foo', value=b',115285708497149_1457362394289467,Goodtimes at Winni Slalom, great course.,,status,,2016-06-27 05:38:30,13,2,0,13,0,0,0,0,0', checksum=-1848879265, serialized_key_size=3, serialized_value_size=123)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=429, timestamp=1483508603116, timestamp_type=0, key=b'foo', value=b',115285708497149_1456062404419466,,,photo,https://www.facebook.com/photo.php?fbid=10101761562017635&set=gm.1456062404419466&type=3,2016-06-25 15:48:36,3,1,0,3,0,0,0,0,0', checksum=-2128963747, serialized_key_size=3, serialized_value_size=168)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=430, timestamp=1483508603555, timestamp_type=0, key=b'foo', value=b',115285708497149_1456062977752742,,,photo,https://www.facebook.com/photo.php?fbid=10101761563110445&set=gm.1456062977752742&type=3,2016-06-25 15:49:59,8,0,0,8,0,0,0,0,0', checksum=695539448, serialized_key_size=3, serialized_value_size=168)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=431, timestamp=1483508604014, timestamp_type=0, key=b'foo', value=b',115285708497149_1454324997926540,Do you paddle? Yes, then help a city and future paddlers.,Outdoor New England,link,https://www.indiegogo.com/projects/1775136?ref=gogo__fblk,2016-06-23 18:28:51,6,0,0,6,0,0,0,0,0', checksum=-2062008731, serialized_key_size=3, serialized_value_size=212)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=432, timestamp=1483508604452, timestamp_type=0, key=b'foo', value=b',115285708497149_1446271438731896,Are the Tville race results ready for posting?  Curious about my times and gates and such.  Thanks!,,status,,2016-06-14 15:18:30,2,0,0,2,0,0,0,0,0', checksum=-2054524314, serialized_key_size=3, serialized_value_size=180)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=433, timestamp=1483508604874, timestamp_type=0, key=b'foo', value=b',115285708497149_1443091559049884,More Tville awards: k1w cadet,,photo,https://www.facebook.com/photo.php?fbid=10209091319262008&set=gm.1443091559049884&type=3,2016-06-10 22:07:38,7,0,0,7,0,0,0,0,0', checksum=-1877117219, serialized_key_size=3, serialized_value_size=197)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=434, timestamp=1483508605296, timestamp_type=0, key=b'foo', value=b',115285708497149_1443090419049998,Tariffville section C gate judges, session A,,photo,https://www.facebook.com/photo.php?fbid=10209091305301659&set=gm.1443090419049998&type=3,2016-06-10 22:05:28,4,0,0,4,0,0,0,0,0', checksum=-1831311029, serialized_key_size=3, serialized_value_size=212)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=435, timestamp=1483508605708, timestamp_type=0, key=b'foo', value=b',115285708497149_1441024605923246,After I posted about the Northeast Regional Team, I learned that there is not going to be a regional team training camp this year.  The national team coaches are concentrating on the Olympics and racing in Europe and there is no funding for it.  In a last ditch effort to keep it going, I asked the Nantahala Racing Club if they could organize it, but they declined.  So, there is no regional team training camp this year.  Apologies to anyone who went to the races thinking they could qualify for the team.  On the other hand, I am going to take a couple of kids to Charlotte to train the week before Junior Olympics at NOC, July 23-30.  So, if you are interested in going to Charlotte and paddling there that week, then going to Junior Olympics at NOC, contact me.  It is too far for us to go to Charlotte on weekends, so hot crowded summer is the best time for us to go.  Without sufficient practice at Charlotte, it is impossible to race there.  If you are interested, contact me: rlugbill@gmail.com. - Ron Lugbill,,status,,2016-06-08 15:39:16,3,0,0,3,0,0,0,0,0', checksum=1516143501, serialized_key_size=3, serialized_value_size=1099)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=436, timestamp=1483508606147, timestamp_type=0, key=b'foo', value=b',115285708497149_1440875132604860,If you are at Tville please keep your eyes peeld for a pair of eye glasses at the dead end parking area.  They disapeared Sunday afternoon after the slalom race during the rainstorm.,,status,,2016-06-08 11:30:44,0,1,0,0,0,0,0,0,0', checksum=539471479, serialized_key_size=3, serialized_value_size=263)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=437, timestamp=1483508606585, timestamp_type=0, key=b'foo', value=b",115285708497149_1437828012909572,Awards photos from Tville! Thanks for a great race!!,Photos from Barrett Phillips's post,photo,https://www.facebook.com/photo.php?fbid=10100320609383080&set=gm.1437828012909572&type=3,2016-06-05 17:19:27,17,1,0,17,0,0,0,0,0", checksum=1740555650, serialized_key_size=3, serialized_value_size=257)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=438, timestamp=1483508607037, timestamp_type=0, key=b'foo', value=b',115285708497149_1436803713012002,Apologies for not getting over to T-ville to help out this weekend. Work-work has reared its ugly head and I am now on deadline. Maybe in July for the Triple ....,,status,,2016-06-04 09:50:44,2,0,0,2,0,0,0,0,0', checksum=-353239427, serialized_key_size=3, serialized_value_size=243)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=439, timestamp=1483508607461, timestamp_type=0, key=b'foo', value=b",115285708497149_1436158033076570,Almost done!,Photos from Amy Sullivan's post,photo,https://www.facebook.com/photo.php?fbid=10209102310585550&set=gm.1436158033076570&type=3,2016-06-03 12:30:19,5,1,0,5,0,0,0,0,0", checksum=-1072359610, serialized_key_size=3, serialized_value_size=211)
# hi
# ConsumerRecord(topic='test2', partition=0, offset=440, timestamp=1483508607907, timestamp_type=0, key=b'foo', value=b',115285708497149_1435627946462912,Again, anyone who wants to hang gates with Gary V. Grosclaude and me.  We will be there at 9:15 ish.  Looking forward to rivers edge work.,,status,,2016-06-02 21:42:09,2,4,0,2,0,0,0,0,0', checksum=525902893, serialized_key_size=3, serialized_value_size=219)

# %%
#Now that the test is working let's try spark streaming 
import findspark
findspark.init()
from pyspark import SparkContext
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils
import findspark
import sys
sc = SparkContext(appName="PythonStreamingDirectKafkaWordCount")
ssc = StreamingContext(sc, 2)
brokers, topic = sys.argv[1:]
kvs = KafkaUtils.createStream(stream, \
                                       "localhost:2181", \
                                       "raw-event-streaming-consumer",
                                        {"pageviews":1})
lines = kvs.map(lambda x: x[1])
counts = lines.flatMap(lambda line: line.split(" ")) \
        .map(lambda word: (word, 1)) \
        .reduceByKey(lambda a, b: a+b)
counts.pprint()
ssc.start()
ssc.awaitTermination()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-521eb8a575a8> in <module>()
#       8 sc = SparkContext(appName="PythonStreamingDirectKafkaWordCount")
#       9 ssc = StreamingContext(sc, 2)
# ---> 10 brokers, topic = sys.argv[1:]
#      11 kvs = KafkaUtils.createDirectStream(ssc, [topic], {"metadata.broker.list": brokers})
#      12 lines = kvs.map(lambda x: x[1])
#
# NameError: name 'sys' is not defined
